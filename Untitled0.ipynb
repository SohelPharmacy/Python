# %% [markdown]
# <a href="https://colab.research.google.com/github/SohelPharmacy/Python/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **welcome programe**

# %% [markdown]
# ## **2nd section**

# %%
print("Welcome to skill morph and class")
# Out:
# Welcome to skill morph and class
